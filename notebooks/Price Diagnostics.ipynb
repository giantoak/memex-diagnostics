# %% [markdown]
# Price Extraction Diagnostics
# =============================
#
# Is the ability to extract prices independent of other characteristics? We want low correlation between ability to extract price and MSA traits. (correlation matrix of # of ads with zero-time price, avg count of prices per ad, and MSA traits).
#
# Variations: drop outliers
# Four-column table: # of ads w/ extractions, avg extractions per ad, same without outliers
#
# --> Distribution plots of prices (histogram of 0/hr,1/hr prices, by MSA/state). (shows that prices are not uniform by MSA)

# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pylab
import seaborn

# all_merged contains MSA-level covariates
all_merged = pd.read_csv('/mnt/stanford-dump-2/data/all_merged.csv')

# %%
print(all_merged.shape)
print(all_merged.columns)
all_merged.head()
# Out:
# (10710, 31)
# Index([u'month', u'year', u'census_msa_code', u'area_fips', u'male_p50', u'male_p25', u'male_p75', u'male_mean.wage', u'male_sum.wght', u'population', u'unemployment', u'lt_highschool', u'highschool', u'some_college', u'college_plus', u'frac_white', u'avg_commute', u'MSA', u'msaname', u'total_reports', u'female_violence_fraction', u'female_violence_counts', u'violence_fraction', u'violence_counts', u'prostitution_fraction', u'prostitution_counts', u'female_p50', u'female_p25', u'female_p75', u'female_mean.wage', u'female_sum.wght'], dtype='object')
#    month  year census_msa_code area_fips   male_p50   male_p25   male_p75  \
# 0      1  2011    31000US10180     C1018  14.972276  10.267497  22.916883
# 1      1  2011    31000US10420     C1042  18.020861  12.578394  26.742999
# 2      1  2011    31000US10500     C1050  16.476696   9.437388  28.089049
# 3      1  2011    31000US10580     C1058  17.949002  12.386021  25.416924
# ...

# %% [markdown]
# We need to aggregate the proportion of ads that have extracted prices up to the MSA level.
